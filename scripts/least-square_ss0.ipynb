# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from implementations import *
from helpers_optimization import *
from helpers_data import *
from helpers_visualization import *
import os
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
DATA_TRAIN_PATH = os.path.dirname(os.getcwd()) + '/data/train.csv'
y, tX, ids = load_csv_data(DATA_TRAIN_PATH) # labels/predictions, id of each sample, tX - 30 features of each sample (float)
labels_feature = np.genfromtxt(DATA_TRAIN_PATH, delimiter=",", dtype=str, max_rows=1)[2:]

# %%
# Splitting the dataset based on the value of PRI_jet_num and 
# removing undefined features for the corresponding subsets
ss0_tX, ss0_y, ss1_tX, ss1_y, ss2_tX, ss2_y, ss3_tX, ss3_y, labels_feat = split_subsets(tX, y,labels_feature)
# Out:
# Subset 0 contains 99913 samples
# Subset 1 contains 77544 samples
# Subset 2 contains 50379 samples
# Subset 3 contains 22164 samples
# Remaining features for subset 2, 3: ['DER_mass_MMC' 'DER_mass_transverse_met_lep' 'DER_mass_vis' 'DER_pt_h'
#  'DER_deltaeta_jet_jet' 'DER_mass_jet_jet' 'DER_prodeta_jet_jet'
#  'DER_deltar_tau_lep' 'DER_pt_tot' 'DER_sum_pt' 'DER_pt_ratio_lep_tau'
#  'DER_met_phi_centrality' 'DER_lep_eta_centrality' 'PRI_tau_pt'
#  'PRI_tau_eta' 'PRI_tau_phi' 'PRI_lep_pt' 'PRI_lep_eta' 'PRI_lep_phi'
#  'PRI_met' 'PRI_met_phi' 'PRI_met_sumet' 'PRI_jet_leading_pt'
#  'PRI_jet_leading_eta' 'PRI_jet_leading_phi' 'PRI_jet_subleading_pt'
#  'PRI_jet_subleading_eta' 'PRI_jet_subleading_phi' 'PRI_jet_all_pt']
# Remaining features for subset 1: ['DER_mass_MMC' 'DER_mass_transverse_met_lep' 'DER_mass_vis' 'DER_pt_h'
#  'DER_deltar_tau_lep' 'DER_pt_tot' 'DER_sum_pt' 'DER_pt_ratio_lep_tau'
#  'DER_met_phi_centrality' 'PRI_tau_pt' 'PRI_tau_eta' 'PRI_tau_phi'
#  'PRI_lep_pt' 'PRI_lep_eta' 'PRI_lep_phi' 'PRI_met' 'PRI_met_phi'
#  'PRI_met_sumet' 'PRI_jet_leading_pt' 'PRI_jet_leading_eta'
#  'PRI_jet_leading_phi' 'PRI_jet_all_pt']
# Remaining features for subset 0: ['DER_mass_MMC' 'DER_mass_transverse_met_lep' 'DER_mass_vis' 'DER_pt_h'
#  'DER_deltar_tau_lep' 'DER_pt_tot' 'DER_sum_pt' 'DER_pt_ratio_lep_tau'
#  'DER_met_phi_centrality' 'PRI_tau_pt' 'PRI_tau_eta' 'PRI_tau_phi'
#  'PRI_lep_pt' 'PRI_lep_eta' 'PRI_lep_phi' 'PRI_met' 'PRI_met_phi'
#  'PRI_met_sumet']

# %%
ss_y = ss0_y
ss_tX = ss0_tX

# %%
# RMSE - With Outliers ==> Singular matrix !


lambdas = []
degrees = np.linspace(9,15,7, dtype=int)

loss_tr = []
loss_te = []  
w = []
accuracy = []

for deg in (degrees):
    loss_tr_tmp, loss_te_tmp, w_tmp, acc_tmp = cross_validation_demo(ss_y, ss_tX, deg, seed = 5, k_fold = 5, class_distribution = False, error = 'rmse', method = 'ls', feature_augmentation=False, hyperparams=[lambdas, False])
    loss_tr.append(loss_tr_tmp)
    loss_te.append(loss_te_tmp)
    w.append(w_tmp)
    accuracy.append(acc_tmp)
    result_crossval(loss_tr_tmp,loss_te_tmp,deg)
    result_crossval_accuracy(acc_tmp,deg)
    print(np.mean(acc_tmp,axis=1))
# Out:
# Number of remaining samples before start cross val : 99913
# Proportion of Bosons in all train set : 25.514197351695977 %
# Proportion of Bosons in test fold 1: 25.12261034931438 %
# [0.7942248]
# Number of remaining samples before start cross val : 99913
# Proportion of Bosons in all train set : 25.514197351695977 %
# Proportion of Bosons in test fold 1: 25.12261034931438 %
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-17-b0966375ef7b> in <module>
#      11
#      12 for deg in (degrees):
# ---> 13     loss_tr_tmp, loss_te_tmp, w_tmp, acc_tmp = cross_validation_demo(ss_y, ss_tX, deg, seed = 5, k_fold = 5, class_distribution = False, error = 'classification', method = 'ls', hyperparams=[lambdas, False])
#      14     loss_tr.append(loss_tr_tmp)
#      15     loss_te.append(loss_te_tmp)
#
# ~\Documents\GitHub\MLProject1\scripts\implementations.py in cross_validation_demo(y, x, degree, seed, k_fold, class_distribution, error, method, hyperparams)
#     467
#     468     # cross validation
# --> 469     loss_tr, loss_te, w, accuracy = choose_method(y, x, degree, seed, k_fold, k_indices, error, method, hyperparams)
#     470
#     471
#
# ~\Documents\GitHub\MLProject1\scripts\implementations.py in choose_method(y, x, degree, seed, k_fold, k_indices, error, method, hyperparams)
#     541             w.append(w_tmp)
#     542     elif method == 'ls':
# --> 543         loss_tr_tmp, loss_te_tmp, w_tmp, acc_tmp= single_cross_val(y, x, degree, k_fold, k_indices, method,error,hyperparams)
#     544         loss_tr.append(concate_fold(loss_tr_tmp))
#     545         loss_te.append(concate_fold(loss_te_tmp))
#
# ~\Documents\GitHub\MLProject1\scripts\implementations.py in single_cross_val(y, x, degree, k_fold, k_indices, method, error, hyperparams)
#     587
#     588     for k in range(k_fold):
# --> 589         loss_tr, loss_te, w , acc = cross_validation(y, x, degree, k, k_indices, method, error, hyperparams)
#     590         loss_tr_tmp.append(loss_tr)
#     591         loss_te_tmp.append(loss_te)
#
# ~\Documents\GitHub\MLProject1\scripts\implementations.py in cross_validation(y, x, degree, k, k_indices, method, error, hyperparams)
#     433
#     434     if method == 'rr': w = ridge_regression(y_tr, tx_tr, hyperparams[0]) # ridge regression
# --> 435     elif method == 'ls': w = least_squares(y_tr, tx_tr) # least square
#     436     elif method == 'lsGD': w = least_squares_GD(y_tr, tx_tr, hyperparams[0], hyperparams[1], hyperparams[2]) # gradient descent
#     437     elif method == 'lsSGD': w = least_squares_SGD(y_tr, tx_tr, hyperparams[0], hyperparams[1], hyperparams[2], hyperparams[3]) # stoch GD
#
# ~\Documents\GitHub\MLProject1\scripts\implementations.py in least_squares(y, tx)
#     346 def least_squares(y, tx):
#     347     """Least squares optimisation. Returns the optimal weights vector"""
# --> 348     weights = np.linalg.solve(tx.T.dot(tx), tx.T.dot(y))
#     349
#     350     #print("Least squares: w={}".format(weights))
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in solve(a, b)
#     401     signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     402     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 403     r = gufunc(a, b, signature=signature, extobj=extobj)
#     404
#     405     return wrap(r.astype(result_t, copy=False))
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_singular(err, flag)
#      95
#      96 def _raise_linalgerror_singular(err, flag):
# ---> 97     raise LinAlgError("Singular matrix")
#      98
#      99 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %%
# RMSE - With Outliers ==> Singular matrix !

lambdas = []
degrees = np.linspace(11,15,7, dtype=int) #car degré 10 singular matrix

loss_tr = []
loss_te = []  
w = []
accuracy = []

for deg in (degrees):
    loss_tr_tmp, loss_te_tmp, w_tmp, acc_tmp = cross_validation_demo(ss_y, ss_tX, deg, seed = 5, k_fold = 5, class_distribution = False, error = 'rmse', method = 'ls', feature_augmentation=False, hyperparams=[lambdas, False])
    loss_tr.append(loss_tr_tmp)
    loss_te.append(loss_te_tmp)
    w.append(w_tmp)
    accuracy.append(acc_tmp)
    result_crossval(loss_tr_tmp,loss_te_tmp,deg)
    result_crossval_accuracy(acc_tmp,deg)
    print(np.mean(acc_tmp,axis=1))
# Out:
# Number of remaining samples before start cross val : 99913
# Proportion of Bosons in all train set : 25.514197351695977 %
# Proportion of Bosons in test fold 1: 25.12261034931438 %
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-16-d6698eaf117d> in <module>
#      10
#      11 for deg in (degrees):
# ---> 12     loss_tr_tmp, loss_te_tmp, w_tmp, acc_tmp = cross_validation_demo(ss_y, ss_tX, deg, seed = 5, k_fold = 5, class_distribution = False, error = 'rmse', method = 'ls', hyperparams=[lambdas, False])
#      13     loss_tr.append(loss_tr_tmp)
#      14     loss_te.append(loss_te_tmp)
#
# ~\Documents\GitHub\MLProject1\scripts\implementations.py in cross_validation_demo(y, x, degree, seed, k_fold, class_distribution, error, method, hyperparams)
#     467
#     468     # cross validation
# --> 469     loss_tr, loss_te, w, accuracy = choose_method(y, x, degree, seed, k_fold, k_indices, error, method, hyperparams)
#     470
#     471
#
# ~\Documents\GitHub\MLProject1\scripts\implementations.py in choose_method(y, x, degree, seed, k_fold, k_indices, error, method, hyperparams)
#     541             w.append(w_tmp)
#     542     elif method == 'ls':
# --> 543         loss_tr_tmp, loss_te_tmp, w_tmp, acc_tmp= single_cross_val(y, x, degree, k_fold, k_indices, method,error,hyperparams)
#     544         loss_tr.append(concate_fold(loss_tr_tmp))
#     545         loss_te.append(concate_fold(loss_te_tmp))
#
# ~\Documents\GitHub\MLProject1\scripts\implementations.py in single_cross_val(y, x, degree, k_fold, k_indices, method, error, hyperparams)
#     587
#     588     for k in range(k_fold):
# --> 589         loss_tr, loss_te, w , acc = cross_validation(y, x, degree, k, k_indices, method, error, hyperparams)
#     590         loss_tr_tmp.append(loss_tr)
#     591         loss_te_tmp.append(loss_te)
#
# ~\Documents\GitHub\MLProject1\scripts\implementations.py in cross_validation(y, x, degree, k, k_indices, method, error, hyperparams)
#     433
#     434     if method == 'rr': w = ridge_regression(y_tr, tx_tr, hyperparams[0]) # ridge regression
# --> 435     elif method == 'ls': w = least_squares(y_tr, tx_tr) # least square
#     436     elif method == 'lsGD': w = least_squares_GD(y_tr, tx_tr, hyperparams[0], hyperparams[1], hyperparams[2]) # gradient descent
#     437     elif method == 'lsSGD': w = least_squares_SGD(y_tr, tx_tr, hyperparams[0], hyperparams[1], hyperparams[2], hyperparams[3]) # stoch GD
#
# ~\Documents\GitHub\MLProject1\scripts\implementations.py in least_squares(y, tx)
#     346 def least_squares(y, tx):
#     347     """Least squares optimisation. Returns the optimal weights vector"""
# --> 348     weights = np.linalg.solve(tx.T.dot(tx), tx.T.dot(y))
#     349
#     350     #print("Least squares: w={}".format(weights))
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in solve(a, b)
#     401     signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     402     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 403     r = gufunc(a, b, signature=signature, extobj=extobj)
#     404
#     405     return wrap(r.astype(result_t, copy=False))
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_singular(err, flag)
#      95
#      96 def _raise_linalgerror_singular(err, flag):
# ---> 97     raise LinAlgError("Singular matrix")
#      98
#      99 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %%
# RMSE - Without Outliers


lambdas = []
degrees = np.linspace(9,15,7, dtype=int)

loss_tr = []
loss_te = []  
w = []
accuracy = []

for deg in (degrees):
    loss_tr_tmp, loss_te_tmp, w_tmp, acc_tmp = cross_validation_demo(ss_y, ss_tX, deg, seed = 5, k_fold = 5, class_distribution = False, error = 'rmse', method = 'ls', feature_augmentation=False, hyperparams=[lambdas, True])
    loss_tr.append(loss_tr_tmp)
    loss_te.append(loss_te_tmp)
    w.append(w_tmp)
    accuracy.append(acc_tmp)
    result_crossval(loss_tr_tmp,loss_te_tmp,deg)
    result_crossval_accuracy(acc_tmp,deg)
    print(np.mean(acc_tmp,axis=1))
# Out:
# Number of remaining samples before start cross val : 99913
# Proportion of Bosons in all train set : 25.514197351695977 %
# Proportion of Bosons in test fold 1: 25.12261034931438 %
# size of the dataset with (79928, 18) and without (75372, 18) the outliers
# Number of sample suppressed oustide 3 std: 4556
# size of the dataset with (79928, 18) and without (74825, 18) the outliers
# Number of sample suppressed oustide 3 std: 5103
# size of the dataset with (79928, 18) and without (75349, 18) the outliers
# Number of sample suppressed oustide 3 std: 4579
# size of the dataset with (79928, 18) and without (75352, 18) the outliers
# Number of sample suppressed oustide 3 std: 4576
# size of the dataset with (79928, 18) and without (75304, 18) the outliers
# Number of sample suppressed oustide 3 std: 4624
# [0.82369132]
# Number of remaining samples before start cross val : 99913
# Proportion of Bosons in all train set : 25.514197351695977 %
# Proportion of Bosons in test fold 1: 25.12261034931438 %
# size of the dataset with (79928, 18) and without (75372, 18) the outliers
# Number of sample suppressed oustide 3 std: 4556
# size of the dataset with (79928, 18) and without (74825, 18) the outliers
# Number of sample suppressed oustide 3 std: 5103
# size of the dataset with (79928, 18) and without (75349, 18) the outliers
# Number of sample suppressed oustide 3 std: 4579
# size of the dataset with (79928, 18) and without (75352, 18) the outliers
# Number of sample suppressed oustide 3 std: 4576
# size of the dataset with (79928, 18) and without (75304, 18) the outliers
# Number of sample suppressed oustide 3 std: 4624
# [0.83435092]
# Number of remaining samples before start cross val : 99913
# Proportion of Bosons in all train set : 25.514197351695977 %
# Proportion of Bosons in test fold 1: 25.12261034931438 %
# size of the dataset with (79928, 18) and without (75372, 18) the outliers
# Number of sample suppressed oustide 3 std: 4556
# size of the dataset with (79928, 18) and without (74825, 18) the outliers
# Number of sample suppressed oustide 3 std: 5103
# size of the dataset with (79928, 18) and without (75349, 18) the outliers
# Number of sample suppressed oustide 3 std: 4579
# size of the dataset with (79928, 18) and without (75352, 18) the outliers
# Number of sample suppressed oustide 3 std: 4576
# size of the dataset with (79928, 18) and without (75304, 18) the outliers
# Number of sample suppressed oustide 3 std: 4624
# [0.83472125]
# Number of remaining samples before start cross val : 99913
# Proportion of Bosons in all train set : 25.514197351695977 %
# Proportion of Bosons in test fold 1: 25.12261034931438 %
# size of the dataset with (79928, 18) and without (75372, 18) the outliers
# Number of sample suppressed oustide 3 std: 4556
# size of the dataset with (79928, 18) and without (74825, 18) the outliers
# Number of sample suppressed oustide 3 std: 5103
# size of the dataset with (79928, 18) and without (75349, 18) the outliers
# Number of sample suppressed oustide 3 std: 4579
# size of the dataset with (79928, 18) and without (75352, 18) the outliers
# Number of sample suppressed oustide 3 std: 4576
# size of the dataset with (79928, 18) and without (75304, 18) the outliers
# Number of sample suppressed oustide 3 std: 4624
# [0.83218897]
# Number of remaining samples before start cross val : 99913
# Proportion of Bosons in all train set : 25.514197351695977 %
# Proportion of Bosons in test fold 1: 25.12261034931438 %
# size of the dataset with (79928, 18) and without (75372, 18) the outliers
# Number of sample suppressed oustide 3 std: 4556
# size of the dataset with (79928, 18) and without (74825, 18) the outliers
# Number of sample suppressed oustide 3 std: 5103
# size of the dataset with (79928, 18) and without (75349, 18) the outliers
# Number of sample suppressed oustide 3 std: 4579
# size of the dataset with (79928, 18) and without (75352, 18) the outliers
# Number of sample suppressed oustide 3 std: 4576
# size of the dataset with (79928, 18) and without (75304, 18) the outliers
# Number of sample suppressed oustide 3 std: 4624
# [0.82461215]
# Number of remaining samples before start cross val : 99913
# Proportion of Bosons in all train set : 25.514197351695977 %
# Proportion of Bosons in test fold 1: 25.12261034931438 %
# size of the dataset with (79928, 18) and without (75372, 18) the outliers
# Number of sample suppressed oustide 3 std: 4556
# size of the dataset with (79928, 18) and without (74825, 18) the outliers
# Number of sample suppressed oustide 3 std: 5103
# size of the dataset with (79928, 18) and without (75349, 18) the outliers
# Number of sample suppressed oustide 3 std: 4579
# size of the dataset with (79928, 18) and without (75352, 18) the outliers
# Number of sample suppressed oustide 3 std: 4576
# size of the dataset with (79928, 18) and without (75304, 18) the outliers
# Number of sample suppressed oustide 3 std: 4624
# [0.83034731]
# Number of remaining samples before start cross val : 99913
# Proportion of Bosons in all train set : 25.514197351695977 %
# Proportion of Bosons in test fold 1: 25.12261034931438 %
# size of the dataset with (79928, 18) and without (75372, 18) the outliers
# Number of sample suppressed oustide 3 std: 4556
# size of the dataset with (79928, 18) and without (74825, 18) the outliers
# Number of sample suppressed oustide 3 std: 5103
# size of the dataset with (79928, 18) and without (75349, 18) the outliers
# Number of sample suppressed oustide 3 std: 4579
# size of the dataset with (79928, 18) and without (75352, 18) the outliers
# Number of sample suppressed oustide 3 std: 4576
# size of the dataset with (79928, 18) and without (75304, 18) the outliers
# Number of sample suppressed oustide 3 std: 4624
# [0.82227004]
