# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from proj1_helpers import *
from implementations import * 
import os
# %load_ext autoreload
# %autoreload 2

# %%
DATA_TRAIN_PATH = os.path.dirname(os.getcwd()) + '/data/train.csv'
y, tX, ids = load_csv_data(DATA_TRAIN_PATH) # labels/predictions, id of each sample, tX - 30 features of each sample (float)
labels_feature = np.genfromtxt(DATA_TRAIN_PATH, delimiter=",", dtype=str, max_rows=1)[2:]

# %%
# Splitting the dataset based on the value of PRI_jet_num and 
# removing undefined features for the corresponding subsets
ss0_tX, ss0_y, ss1_tX, ss1_y, ss2_tX, ss2_y, ss3_tX, ss3_y, labels_feat = split_subsets(tX, y,labels_feature)
# Out:
# Subset 0 contains 99913 samples
# Subset 1 contains 77544 samples
# Subset 2 contains 50379 samples
# Subset 3 contains 22164 samples
# Remaining features for subset 2, 3: ['DER_mass_MMC' 'DER_mass_transverse_met_lep' 'DER_mass_vis' 'DER_pt_h'
#  'DER_deltaeta_jet_jet' 'DER_mass_jet_jet' 'DER_prodeta_jet_jet'
#  'DER_deltar_tau_lep' 'DER_pt_tot' 'DER_sum_pt' 'DER_pt_ratio_lep_tau'
#  'DER_met_phi_centrality' 'DER_lep_eta_centrality' 'PRI_tau_pt'
#  'PRI_tau_eta' 'PRI_tau_phi' 'PRI_lep_pt' 'PRI_lep_eta' 'PRI_lep_phi'
#  'PRI_met' 'PRI_met_phi' 'PRI_met_sumet' 'PRI_jet_leading_pt'
#  'PRI_jet_leading_eta' 'PRI_jet_leading_phi' 'PRI_jet_subleading_pt'
#  'PRI_jet_subleading_eta' 'PRI_jet_subleading_phi' 'PRI_jet_all_pt']
# Remaining features for subset 1: ['DER_mass_MMC' 'DER_mass_transverse_met_lep' 'DER_mass_vis' 'DER_pt_h'
#  'DER_deltar_tau_lep' 'DER_pt_tot' 'DER_sum_pt' 'DER_pt_ratio_lep_tau'
#  'DER_met_phi_centrality' 'PRI_tau_pt' 'PRI_tau_eta' 'PRI_tau_phi'
#  'PRI_lep_pt' 'PRI_lep_eta' 'PRI_lep_phi' 'PRI_met' 'PRI_met_phi'
#  'PRI_met_sumet' 'PRI_jet_leading_pt' 'PRI_jet_leading_eta'
#  'PRI_jet_leading_phi' 'PRI_jet_all_pt']
# Remaining features for subset 0: ['DER_mass_MMC' 'DER_mass_transverse_met_lep' 'DER_mass_vis' 'DER_pt_h'
#  'DER_deltar_tau_lep' 'DER_pt_tot' 'DER_sum_pt' 'DER_pt_ratio_lep_tau'
#  'DER_met_phi_centrality' 'PRI_tau_pt' 'PRI_tau_eta' 'PRI_tau_phi'
#  'PRI_lep_pt' 'PRI_lep_eta' 'PRI_lep_phi' 'PRI_met' 'PRI_met_phi'
#  'PRI_met_sumet']

# %%
ss_y = ss3_y
ss_tX = ss3_tX

# %%
# RMSE - Outliers false / false

lambdas = np.logspace(-15, -3, 11)
degrees = np.linspace(9,15,7, dtype=int)

loss_tr = []
loss_te = []  
w = []
accuracy = []

for deg in (degrees):
    loss_tr_tmp, loss_te_tmp, w_tmp, acc_tmp = cross_validation_demo(ss_y, ss_tX, deg, seed = 5, k_fold = 5, class_distribution = False, error = 'rmse', method = 'rr',hyperparams=[lambdas, False])
    loss_tr.append(loss_tr_tmp)
    loss_te.append(loss_te_tmp)
    w.append(w_tmp)
    accuracy.append(acc_tmp)
    result_crossval(loss_tr_tmp,loss_te_tmp,deg)
    result_crossval_accuracy(acc_tmp,deg)
# Out:
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %

# %%
# Classification - Outliers false / false

lambdas = np.logspace(-15, -3, 11)
degrees = np.linspace(9,15,7, dtype=int)

loss_tr = []
loss_te = []  
w = []
accuracy = []

for deg in (degrees):
    loss_tr_tmp, loss_te_tmp, w_tmp, acc_tmp = cross_validation_demo(ss_y, ss_tX, deg, seed = 5, k_fold = 5, class_distribution = False, error = 'classification', method = 'rr',hyperparams=[lambdas, False])
    loss_tr.append(loss_tr_tmp)
    loss_te.append(loss_te_tmp)
    w.append(w_tmp)
    accuracy.append(acc_tmp)
    result_crossval(loss_tr_tmp,loss_te_tmp,deg)
    result_crossval_accuracy(acc_tmp,deg)
# Out:
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %

# %%
# Class - Outliers false / false

lambdas = np.logspace(-15, -3, 11)
degrees = np.linspace(9,15,7, dtype=int)

loss_tr = []
loss_te = []  
w = []
accuracy = []

for deg in (degrees):
    loss_tr_tmp, loss_te_tmp, w_tmp, acc_tmp = cross_validation_demo(ss_y, ss_tX, deg, seed = 5, k_fold = 5, class_distribution = False, error = 'class', method = 'rr',hyperparams=[lambdas, False])
    loss_tr.append(loss_tr_tmp)
    loss_te.append(loss_te_tmp)
    w.append(w_tmp)
    accuracy.append(acc_tmp)
    result_crossval(loss_tr_tmp,loss_te_tmp,deg)
    result_crossval_accuracy(acc_tmp,deg)
# Out:
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %

# %%
# RMSE - Outliers true / false

lambdas = np.logspace(-15, -3, 11)
degrees = np.linspace(9,15,7, dtype=int)

loss_tr = []
loss_te = []  
w = []
accuracy = []

for deg in (degrees):
    loss_tr_tmp, loss_te_tmp, w_tmp, acc_tmp = cross_validation_demo(ss_y, ss_tX, deg, seed = 5, k_fold = 5, class_distribution = False, error = 'rmse', method = 'rr',hyperparams=[lambdas, True])
    loss_tr.append(loss_tr_tmp)
    loss_te.append(loss_te_tmp)
    w.append(w_tmp)
    accuracy.append(acc_tmp)
    result_crossval(loss_tr_tmp,loss_te_tmp,deg)
    result_crossval_accuracy(acc_tmp,deg)
# Out:
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %

# %%
# Class - Outliers true / false

lambdas = np.logspace(-15, -3, 11)
degrees = np.linspace(9,15,7, dtype=int)

loss_tr = []
loss_te = []  
w = []
accuracy = []

for deg in (degrees):
    loss_tr_tmp, loss_te_tmp, w_tmp, acc_tmp = cross_validation_demo(ss_y, ss_tX, deg, seed = 5, k_fold = 5, class_distribution = False, error = 'class', method = 'rr',hyperparams=[lambdas, True])
    loss_tr.append(loss_tr_tmp)
    loss_te.append(loss_te_tmp)
    w.append(w_tmp)
    accuracy.append(acc_tmp)
    result_crossval(loss_tr_tmp,loss_te_tmp,deg)
    result_crossval_accuracy(acc_tmp,deg)
# Out:
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %

# %%
# Classification - Outliers true / false

lambdas = np.logspace(-15, -3, 11)
degrees = np.linspace(9,15,7, dtype=int)

loss_tr = []
loss_te = []  
w = []
accuracy = []

for deg in (degrees):
    loss_tr_tmp, loss_te_tmp, w_tmp, acc_tmp = cross_validation_demo(ss_y, ss_tX, deg, seed = 5, k_fold = 5, class_distribution = False, error = 'classification', method = 'rr',hyperparams=[lambdas, True])
    loss_tr.append(loss_tr_tmp)
    loss_te.append(loss_te_tmp)
    w.append(w_tmp)
    accuracy.append(acc_tmp)
    result_crossval(loss_tr_tmp,loss_te_tmp,deg)
    result_crossval_accuracy(acc_tmp,deg)
# Out:
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %
# Number of remaining samples before start cross val : 22164
# Proportion of Bosons in all train set : 30.369066955423207 %
# Proportion of Bosons in test fold 1: 29.851083032490976 %

# %%
plot_correlation_matrix(ss_tX, ss_y, labels, figureName="CorrelationMatrix.png", threshold=0.85, print_correlated_pairs=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-8d1d25dcb81b> in <module>()
# ----> 1 plot_correlation_matrix(ss_tX, ss_y, labels, figureName="CorrelationMatrix.png", threshold=0.85, print_correlated_pairs=False)
#       2
#       3
#       4
#
# NameError: name 'labels' is not defined

# %%
# Classification - Outliers false / false

lambdas = np.logspace(-15, -3, 11)
degrees = np.linspace(9,15,7, dtype=int)

loss_tr = []
loss_te = []  
w = []
accuracy = []

for deg in (degrees):
    loss_tr_tmp, loss_te_tmp, w_tmp, acc_tmp = cross_validation_demo_featselect(ss_y, ss_tX, ranked_index, deg, seed, k_fold = 5, class_distribution = False, error ='rmse', method='rr',hyperparams=[lambdas, False])
    loss_tr.append(loss_tr_tmp)
    loss_te.append(loss_te_tmp)
    w.append(w_tmp)
    accuracy.append(acc_tmp)
    result_crossval(loss_tr_tmp,loss_te_tmp,deg)
    result_crossval_accuracy(acc_tmp,deg)
